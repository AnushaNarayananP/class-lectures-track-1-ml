# %% [markdown]
# import libraries

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
car =pd.read_csv('C:\\Users\\LENOVO\\car data.csv')

# %%
car1 =pd.read_csv('C:\\Users\\LENOVO\\car data.csv')

# %%
car2 =pd.read_csv('C:\\Users\\LENOVO\\car data.csv')

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301 entries, 0 to 300
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_Name       301 non-null    object
#  1   Year           301 non-null    int64
#  2   Selling_Price  301 non-null    float64
#  3   Present_Price  301 non-null    float64
#  4   Kms_Driven     301 non-null    int64
#  5   Fuel_Type      301 non-null    object
#  6   Seller_Type    301 non-null    object
#  7   Transmission   301 non-null    object
#  8   Owner          301 non-null    int64
# dtypes: float64(2), int64(3), object(4)
# memory usage: 21.3+ KB

# %%
car.shape
# Out:
# (301, 9)

# %%
car[['2022']]=2022

# %%
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  2022
# 0        Dealer       Manual      0  2022
# ...

# %%
car['year']=car['2022'] - car['Year']
car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner  2022  year
# 0        Dealer       Manual      0  2022     8
# ...

# %%
car.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner  2022  year
# 0      Dealer       Manual      0  2022     8
# 1      Dealer       Manual      0  2022     9
# 2      Dealer       Manual      0  2022     5
# 3      Dealer       Manual      0  2022    11
# 4      Dealer       Manual      0  2022     8

# %%
car.drop(['Car_Name','Year','2022'],axis=1,inplace=True)

# %%
car
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  year
# 0         Manual      0     8
# 1         Manual      0     9
# 2         Manual      0     5
# ...

# %%
car.Fuel_Type.unique()
# Out:
# array(['Petrol', 'Diesel', 'CNG'], dtype=object)

# %%
car.Seller_Type.unique()
# Out:
# array(['Dealer', 'Individual'], dtype=object)

# %%
car.Transmission.unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %%
car.Owner.unique()
# Out:
# array([0, 1, 3], dtype=int64)

# %% [markdown]
# dummies_f=car.Fuel_Type
# dummies_s=car.Seller_Type
# dummies_t=car.Transmission
# dummies_o=car.Owner

# %% [markdown]
# dummies_f = pd.get_dummies(dummies_f)
# dummies_s = pd.get_dummies(dummies_s)
# dummies_t = pd.get_dummies(dummies_t)
# dummies_o = pd.get_dummies(dummies_o)

# %%
car = pd.get_dummies(data = car ,columns=['Fuel_Type','Seller_Type','Transmission','Owner'],drop_first= True)
car
# Out:
#      Selling_Price  Present_Price  Kms_Driven  year  Fuel_Type_Diesel  \
# 0             3.35           5.59       27000     8                 0
# 1             4.75           9.54       43000     9                 1
# 2             7.25           9.85        6900     5                 0
# 3             2.85           4.15        5200    11                 0
# 4             4.60           6.87       42450     8                 1
# ..             ...            ...         ...   ...               ...
# 296           9.50          11.60       33988     6                 1
# 297           4.00           5.90       60000     7                 0
# 298           3.35          11.00       87934    13                 0
# 299          11.50          12.50        9000     5                 1
# 300           5.30           5.90        5464     6                 0
#
#      Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual  Owner_1  \
# ...

# %%
X= car.drop(['Selling_Price'],axis=1)
y= car['Selling_Price']

# %%
X
# Out:
#      Present_Price  Kms_Driven  year  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# 0             5.59       27000     8                 0                 1
# 1             9.54       43000     9                 1                 0
# 2             9.85        6900     5                 0                 1
# 3             4.15        5200    11                 0                 1
# 4             6.87       42450     8                 1                 0
# ..             ...         ...   ...               ...               ...
# 296          11.60       33988     6                 1                 0
# 297           5.90       60000     7                 0                 1
# 298          11.00       87934    13                 0                 1
# 299          12.50        9000     5                 1                 0
# 300           5.90        5464     6                 0                 1
#
#      Seller_Type_Individual  Transmission_Manual  Owner_1  Owner_3
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
min_scaler=MinMaxScaler()

# %%
scaled_data = min_scaler.fit_transform(X)
scaled_data
# Out:
# array([[0.0571088 , 0.05305305, 0.26666667, ..., 1.        , 0.        ,
#         0.        ],
#        [0.09991331, 0.08508509, 0.33333333, ..., 1.        , 0.        ,
#         0.        ],
#        [0.10327265, 0.01281281, 0.06666667, ..., 1.        , 0.        ,
#         0.        ],
#        ...,
#        [0.11573472, 0.17504304, 0.6       , ..., 1.        , 0.        ,
#         0.        ],
#        [0.1319896 , 0.01701702, 0.06666667, ..., 1.        , 0.        ,
#         0.        ],
#        [0.06046814, 0.00993794, 0.13333333, ..., 1.        , 0.        ,
#         0.        ]])

# %%
X_train, X_test, y_train, y_test = train_test_split(scaled_data, y, test_size=0.33, random_state=42)

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(X_test,y_test)
# Out:
# 0.8629024996644388

# %%
y_pred = model.predict(X_test)

# %%
sns.distplot(y_test-y_pred)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Selling_Price', ylabel='Density'>

# %%
from sklearn.neighbors import KNeighborsRegressor
score_list =[]
for i in range(1,15):
    knn=KNeighborsRegressor(n_neighbors=i)
    knn.fit(X_train,y_train)
    score_list.append(knn.score(X_test,y_test))
plt.plot(range(1,15),score_list)
plt.show()

# %%
model =KNeighborsRegressor(n_neighbors = 2)

# %%
model.fit(X_train,y_train)
# Out:
# KNeighborsRegressor(n_neighbors=2)

# %%
model.score(X_test,y_test)
# Out:
# 0.8651277455183418
